# %%
import pandas as pd

# %%
import pandas as pd 

df = pd.read_csv('/home/eduardo-schmegel/Desktop/Projects/fraud_detection/data/fraud_data.csv')

weight = df['isFraud'].value_counts()[0] / df['isFraud'].value_counts()[1]

print (f'Class weight for positive class: {weight}')
# Out:
# Class weight for positive class: 773.7010836478753
